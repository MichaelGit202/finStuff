# %%
from finlib import market

# %%
nyse = market.Market(initial_cash=10000, symbols=["MSFT", "AAPL"])
nyse.step()
nyse.add_cash("MSFT", 5000)
nyse.add_cash("AAPL", 5000)
nyse.step()
print(nyse.stocks["MSFT"].cash)
nyse.buy_stock("MSFT", 5000)
nyse.buy_stock("AAPL", 5000)
# Out:
# 5000.0
